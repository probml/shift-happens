# %% [markdown]
# # Shifting MNIST dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import jax
import optax
import dojax
import jax.numpy as jnp
import flax.linen as nn
import numpy as np
import torchvision
import pandas as pd
import matplotlib.pyplot as plt
from time import time
from augly import image
from sklearn.decomposition import PCA

from multiprocessing import Pool
from loguru import logger

# %%
cpu_count = os.cpu_count()
print(f"Number of cores: {cpu_count}")
# Out:
# Number of cores: 96

# %%
mnist_train = torchvision.datasets.MNIST(root=".", train=True, download=True)
mnist_test = torchvision.datasets.MNIST(root=".", train=False, download=True)

# %%
# %config InlineBackend.figure_format = "retina"
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

# %%
radii = [0.1, 0.5, 1.0, 2.0, 3.0, 4.0]
X_train = np.array(mnist_train.data)
y_train = np.array(mnist_train.targets)

fig, ax = plt.subplots(3, 2, figsize=(4, 6))
for axi, radius in zip(ax.flat, radii):
    x_shift = image.aug_np_wrapper(X_train[0], image.blur, radius=radius)
    axi.imshow(x_shift)
    axi.axis("off")
plt.tight_layout()

# %%
class BlurRad:
    def __init__(self, rad):
        self.rad = rad
        
    def __call__(self, img):
        return self.blur_multiple(img)

    def blur(self, X):
        """
        Blur an image using the augly library

        Paramters
        ---------
        X: np.array
            A single NxM-dimensional array
        radius: float
            The amout of blurriness
        """
        return image.aug_np_wrapper(X, image.blur, radius=self.rad)

    def blur_multiple(self, X_batch):
        images_out = []
        for X in X_batch:
            img_blur = self.blur(X)
            images_out.append(img_blur)
        images_out = np.stack(images_out, axis=0)
        return images_out

# %% [markdown]
# ## Estimating weights

# %%
def make_loss_func(model, X, y):
    def loss_fn(params):
        pred = model.apply(params, X)
        loss = optax.softmax_cross_entropy(pred, y).mean()
        return loss
    return loss_fn # Assuming top-level funciton is jitted
    # return jax.jit(loss_fn) # assuming top-level function is not jitted


class MLPWide(nn.Module):
    num_outputs: int
    @nn.compact
    def __call__(self, x):
        # x = x.reshape(-1, 1)
        x = nn.relu(nn.Dense(800)(x))
        x = nn.relu(nn.Dense(500, name="last_layer")(x))
        x = nn.Dense(self.num_outputs)(x)
        x = nn.log_softmax(x)
        return x

    
def print_progress(epoch, loss, step_mod):
    if epoch % step_mod == 0:
        print(f"Loss step ({epoch}: {loss:0.4e})")


@jax.jit
def train_step(params, opt_state, X_batch, y_batch):
    loss_fn = make_loss_func(model, X_batch, y_batch)
    loss_grad_fn = jax.value_and_grad(loss_fn)
    
    loss_val, grads = loss_grad_fn(params)
    updates, opt_state = tx.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    
    return loss_val, params
    

def get_batch_train_ixs(key, num_samples, batch_size):
    """
    Obtain the training indices to be used in an epoch of
    mini-batch optimisation.
    """
    steps_per_epoch = num_samples // batch_size
    
    batch_ixs = jax.random.permutation(key, num_samples)
    batch_ixs = batch_ixs[:steps_per_epoch * batch_size]
    batch_ixs = batch_ixs.reshape(steps_per_epoch, batch_size)
    
    return batch_ixs


def train_epoch(key, params, opt_step, X, y, batch_size, epoch):
    num_samples = len(X)
    batch_ixs = get_batch_train_ixs(key, num_samples, batch_size)
    
    for batch_ix in batch_ixs:
        X_batch = X[batch_ix, ...]
        y_batch = y[batch_ix, ...]
        loss, params = train_step(params, opt_step, X_batch, y_batch)
    
    return params, opt_step


def proc_dataset(radius, img_dataset, n_processes=90):
    """
    Blur all images of a dataset stored in a numpy array.
    
    Parameters
    ----------
    radius: float
        Intensity of bluriness
    img_dataset: array(N, L, K)
        N images of size LxK
    n_processes: int
        Number of processes to blur over
    """
    pool = Pool(processes=n_processes)
    
    dataset_proc = np.array_split(img_dataset, n_processes)
    dataset_proc = pool.map(BlurRad(radius), dataset_proc)
    dataset_proc = np.concatenate(dataset_proc, axis=0)
    
    pool.close()
    
    return dataset_proc

# %%
key = jax.random.PRNGKey(314)

alpha = 0.001
n_classes = 10
n_subset = 5000
batch_size = 2_000
n_epochs = 150
alpha = 0.001
tx = optax.adam(learning_rate=alpha)

model = MLPWide(n_classes)
# X_train_ravel = X_train_proc.reshape(-1, 28 ** 2)
# y_train_ohe = jax.nn.one_hot(y_train, n_classes)


def train_model_config(key, radius, num_epochs):
    X_train_proc = proc_dataset(radius, X_train, 90)
    X_train_ravel = X_train_proc.reshape(-1, 28 ** 2)
    y_train_ohe = jax.nn.one_hot(y_train, n_classes)

    batch = jnp.ones((1, 28 ** 2))
    params = model.init(key, batch)
    opt_state = tx.init(params)

    for e in range(num_epochs):
        print(f"@epoch {e+1:03}", end="\r")
        _, key = jax.random.split(key)
        params, opt_state = train_epoch(key, params, opt_state, X_train_ravel, y_train_ohe, batch_size, e)

    final_train_acc = (y_train == model.apply(params, X_train_ravel).argmax(axis=1)).mean().item()
    print(f"@{radius=:0.4f}, {final_train_acc=:0.4f}")
    
    return params, final_train_acc

# %% [raw]
# hist_params = []
# hist_accuracy = []
# radii = jnp.linspace(0.001, 3.00, 100)
#
# time_start = time()
# for rad in radii:
#     params, train_acc = train_model_config(key, rad, n_epochs)
#
#     hist_accuracy.append(train_acc)
#     hist_params.append(params)
#
# hist_accuracy = jnp.array(hist_accuracy)
# time_end = time()
# time_total = time_end - time_start
# print(f"Total running time: {time_total:0.2f}s")

# %%
params, train_acc = train_model_config(key, 1, 1) # used to initialise params
_, reconstruct_pytree_fn = jax.flatten_util.ravel_pytree(params)
reconstruct_pytree_fn
# Out:
# @radius=1.0000, final_train_acc=0.7416
# <function jax._src.flatten_util.ravel_pytree.<locals>.<lambda>(flat)>

# %%
filename_params = "mnist_shift_params.npy"
filename_params = os.path.join("outputs/", filename_params)

if os.path.exists(filename_params):
    hist_params_flat = jnp.load(filename_params)
    # hist_accuracy = jnp.load(filename_accuracy)
else:
    hist_params_flat, reconstruct_pytree_fn = dojax.flat_and_concat_params(hist_params)
    jnp.save(filename, hist_params_flat)
    # jnp.save(filename_accuracy, hist_accuracy)

# %%
pca = PCA(n_components=2)
params_proj = pca.fit_transform(hist_params_flat)
params_proj.shape
# Out:
# (100, 2)

# %%
radii = jnp.linspace(0.001, 3.00, 100)

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

ax[0].set_title("Projected weight dynamics: MNIST")
ax[0].scatter(*params_proj.T, c=radii)
# ax[0].cb(label="radius")
ax[0].tick_params(axis="both", labelleft=False, labelbottom=False)
ax[0].axis("equal")

ax[1].set_title("Accuracy")
ax[1].scatter(radii, hist_accuracy, c=radii)
ax[1].set_xlabel("Radius")
ax[1].set_ylabel("Accuracy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_686365/2376947528.py in <module>
#      10
#      11 ax[1].set_title("Accuracy")
# ---> 12 ax[1].scatter(radii, hist_accuracy, c=radii)
#      13 ax[1].set_xlabel("Radius")
#      14 ax[1].set_ylabel("Accuracy")
#
# NameError: name 'hist_accuracy' is not defined

# %%
pca = PCA(n_components=3)
params_proj = pca.fit_transform(hist_params_flat)

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.axes(projection="3d")
ax.view_init(20, 35)
ax.scatter(*params_proj.T, c=radii, s=50);

# %% [markdown]
# ## Modelling weight dynamics

# %%
class MLPWeights(nn.Module):
    num_outputs: int
    @nn.compact
    def __call__(self, x):
        # x = x.reshape(-1, 1)
        x = nn.relu(nn.Dense(200)(x))
        x = nn.Dense(self.num_outputs)(x)
        return x

# %%
pca = PCA(n_components=60)
params_proj = pca.fit_transform(hist_params_flat)

# %% [markdown]
# ### Steps to follow
# 1. Modify `proc_dataset` so that it takes as input a list of radii and images. Both elements should have the same cardinality over the leading dimension. Its output is a list of images.
# 2. Modify `make_loss_fn` so that it considers an output in R^d (d-dimensional output with real-valued entries)
# 3. Modify `get_batch_train_ixs` so that it takes `num_samples` and `num_configs`, where `num_configs` is the total number of configuration. To do this, create a `num_samples x num_configs` count array. Then, given an index `i`, we obtain its config as `i % num_configs`; we obtain its position in the database as `i // num_configs`. Consider the following example:

# %%
num_samples = 10
num_configs = 3

samples_ix = jnp.arange(num_samples * num_configs)

# %%
# Choose configuration
samples_ix.reshape(num_samples, num_configs) % num_configs
# Out:
# DeviceArray([[0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2],
#              [0, 1, 2]], dtype=int32)

# %%
# Choose index
samples_ix.reshape(num_samples, num_configs) // num_configs
# Out:
# DeviceArray([[0, 0, 0],
#              [1, 1, 1],
#              [2, 2, 2],
#              [3, 3, 3],
#              [4, 4, 4],
#              [5, 5, 5],
#              [6, 6, 6],
#              [7, 7, 7],
#              [8, 8, 8],
#              [9, 9, 9]], dtype=int32)

# %%
samples_ix[14] // num_configs
# Out:
# DeviceArray(4, dtype=int32)

# %%
samples_ix[14] % num_configs
# Out:
# DeviceArray(2, dtype=int32)

# %% [markdown]
# 4. Modify `train_step` so that it considers the new `make_loss_fn` defined in step `2.`
#
# 5. Modify `train_epoch` so that it samples from the indices defined in `3.`. Then, it should return a list of indices to train and radii to try. We modify the input X with the list of radii and obtain our target variable (the weights to predict) given by the list of radii. We then call the modified version of `train_step` (`4.`) with the batch as big as possible (so as to minimise the overhead of computing the transformations of `X`)

# %% [markdown]
# ### Implementation

# %%
size_subset = 4
n_processes = 4

np.random.seed(314)
radii = np.random.rand(size_subset) * 5

X_train_subset = X_train[:size_subset, ...]
X_train_subset.shape

res = dojax.proc_dataset_multiple(radii, X_train_subset, n_processes)

fig, ax = plt.subplots(2, 2, figsize=(6, 6))
for radius, axi, img in zip(radii, ax.flat, res):
    axi.imshow(img)
    axi.set_title(f"{radius=:0.2f}")
plt.tight_layout()
# Out:
# https://symbolize.stripped_domain/r/?trace=7f89f39ac76d,7f89f3a9a3bf&map=
# *** SIGTERM received by PID 687990 (TID 687990) on cpu 17 from PID 686365; stack trace: ***
# PC: @     0x7f89f39ac76d  (unknown)  syscall
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f39ac76d,7f89e33487f9,7f89f3a9a3bf&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:33:34.219076  687990 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:33:34.227855  687990 process_state.cc:770] RAW: Raising signal 15 with default behavior

# %% [markdown]
# ## Loss function for multiple outputs
#
# $$
#     \mathcal{L} = \frac{1}{2N}\sum_{n=1}^N \vert\vert {\bf y}_n - {\bf W}^T\phi({\bf x}_n) \vert\vert^2
# $$

# %%
def make_loss_func_multiple(model, X, y):
    """
    Loss function for regression problem with multiple outputs
    """
    def loss_fn(params):
        y_hat = model.apply(params, X)
        loss = jnp.linalg.norm(y - y_hat, axis=-1) ** 2
        return loss.mean()
    return loss_fn

# %%
weight_model = MLPWeights(10)

# %%
batch = jnp.ones((1, 28 ** 2))
params = weight_model.init(key, batch)
opt_state = tx.init(params)

# %%
res = dojax.proc_dataset_multiple(radii, X_train_subset, n_processes)
y_test = jax.random.normal(key, (4, 10)) * 10
y_hat = weight_model.apply(params, res.reshape(4, -1))
# Out:
# https://symbolize.stripped_domain/r/?trace=7f89f39ac76d,7f89f3a9a3bf&map=
# *** SIGTERM received by PID 688046 (TID 688046) on cpu 19 from PID 686365; stack trace: ***
# PC: @     0x7f89f39ac76d  (unknown)  syscall
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f39ac76d,7f89e33487f9,7f89f3a9a3bf&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:33:35.982341  688046 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:33:35.992007  688046 process_state.cc:770] RAW: Raising signal 15 with default behavior

# %% [markdown]
# ### Getting training indices

# %%
def get_batch_train_configs_ixs(num_samples, num_configs, batch_size):
    """
    Obtain the training indices to be used in an epoch of
    mini-batch optimisation
    
    We consider a tranining dataset over number of samples and
    number of configurtios.
    """
    num_elements = num_samples * num_configs
    
    steps_per_epoch = num_elements // batch_size
    
    # Maybe we can only use numpy here to avoid sending /
    # calling elements from the TPU
    # batch_ixs = jax.random.permutation(key, num_elements)
    batch_ixs = np.random.permutation(num_elements)
    batch_ixs = batch_ixs[:steps_per_epoch * batch_size]
    batch_ixs = batch_ixs.reshape(steps_per_epoch, batch_size)
    
    batch_ixs_samples = batch_ixs // num_configs
    batch_ixs_configs = batch_ixs % num_configs
    
    return batch_ixs_samples, batch_ixs_configs

# %% [markdown]
# ### The new training step

# %%
n_configs, dim_params = params_proj.shape
weight_model = MLPWeights(dim_params)

# %%
alpha = 0.0001
tx = optax.adam(learning_rate=alpha)

@jax.jit
def train_step_weights(params, opt_state, X_batch, y_batch):
    loss_fn = make_loss_func_multiple(weight_model, X_batch, y_batch)
    loss_grad_fn = jax.value_and_grad(loss_fn)
    
    loss_val, grads = loss_grad_fn(params)
    updates, opt_state = tx.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    
    return loss_val, params

# %% [markdown]
# ### New training episode

# %%
np.random.seed(314)
batch_size = 100
sample_ixs, config_ixs = get_batch_train_configs_ixs(size_subset, n_configs, batch_size)

# %%
sample_batch_ix = sample_ixs[0]
config_batch_ix = config_ixs[0]

# %%
radii = np.linspace(0.001, 3.00, 100)

X_batch = X_train_subset[sample_batch_ix, ...]
weights_batch = params_proj[config_batch_ix, ...]
config_batch = radii[config_batch_ix]

# %%
n_processes = 20

weight_model = MLPWeights(dim_params)
batch = jnp.ones((1, 28 ** 2))
params = weight_model.init(key, batch)
opt_state = tx.init(params)

# %%
def train_epoch_weights(key, params, opt_step, X, configs, target_weights, batch_size, epoch,
                        logger, n_processes=90):
    """
    Training epoch for the projected weights. Note that target weights are the
    target variables
    """
    num_samples = len(X)
    num_configs = len(target_weights)
    n_processes_batch = min(n_processes, batch_size)
    
    sample_ixs, config_ixs = get_batch_train_configs_ixs(num_samples, num_configs, batch_size)
    
    number_partitions = len(sample_ixs)
    for part, (sample_batch_ix, config_batch_ix) in enumerate(zip(sample_ixs, config_ixs)):
        print(f"{part+1:03}/{number_partitions}", end="\r")
        X_batch = X[sample_batch_ix, ...]
        config_batch = configs[config_batch_ix]
        X_batch_transformed = dojax.proc_dataset_multiple(config_batch, X_batch, n_processes_batch).reshape(-1, 28 ** 2)
        
        weights_batch = target_weights[config_batch_ix, ...]
        loss, params = train_step_weights(params, opt_step, X_batch_transformed, weights_batch)

    logger.info(f"@{epoch=} | {loss=:0.4f}")
    return loss, params, opt_step

# %%
import pandas as pd

n_train_subset = 6_000
subset_ix = pd.Series(y_train).sample(n_train_subset, random_state=314)
subset_ix = subset_ix.index.values
subset_ix
# Out:
# array([46242, 52277, 30471, ..., 18692,  3212,   220])

# %% [markdown]
# ## All together

# %%
logger.add("training-weights.log", rotation="5mb")
# Out:
# 1

# %%
logger.info("Start of messages")
# Out:
# 2022-03-01 18:40:38.088 | INFO     | __main__:<module>:1 - Start of messages

# %%
# %%time
batch_size = 10_000
losses = []
for epoch in range(100):
    loss, params, opt_state = train_epoch_weights(key, params, opt_state, X_train[subset_ix], radii,
                                            params_proj, batch_size, epoch, logger)
    losses.append(loss.item())

# %% [markdown]
# ### Storing and retrieving parameters
#
# ```
# from flax import serialization
# with open("weights-dynamics.params", "wb") as f:
#     bytes_params = serialization.to_bytes(params)
#     f.write(bytes_params)
#
# with open("weights-dynamics.params", "rb") as f:
#     params_reload = serialization.from_bytes(params, f.read())
# ```

# %%
from flax import serialization
with open("weights-dynamics.params", "rb") as f:
    params = serialization.from_bytes(params, f.read())

# %%
predicted_weights = weight_model.apply(params, X_train[0].ravel())
predicted_weights
# Out:
# DeviceArray([ 1.2580140e+01, -6.8292217e+00,  5.5988770e+00,
#               5.2412686e+00, -3.4233327e+00, -3.4819825e+00,
#               3.0162313e+00, -1.2083691e+00,  6.9903374e-01,
#              -1.4069019e-01,  1.9981846e-01,  5.7997191e-01,
#               3.3927101e-01, -5.3004396e-01, -2.1227376e+00,
#              -1.8234313e-01,  6.1534464e-02,  2.2112386e-01,
#              -5.9752184e-01,  2.1245466e-01, -7.2291297e-01,
#              -8.4392510e-02, -2.7413172e-01,  5.8599430e-01,
#              -4.9972087e-01, -2.5991447e-02,  2.7943024e-01,
#               2.7051464e-01,  8.9725369e-01,  4.2745537e-01,
#              -1.9664969e-01,  5.9976465e-01, -2.5679138e+00,
#               1.6165617e-01, -2.1035157e-02, -1.3633877e-01,
#              -1.4357129e+00,  1.0282533e+00,  5.1670261e-03,
#              -1.1178436e+00,  1.9859986e-01, -1.7094951e+00,
#              -1.9074145e-01, -4.1237313e-02,  5.8405496e-02,
#               1.0237057e-02,  1.2696477e+00, -5.2699655e-01,
#               3.5547143e-01, -3.6690113e-01,  1.7504020e+00,
#              -1.3799413e-01, -6.6473120e-01,  4.2921668e-01,
#              -1.0504351e+00,  5.3698766e-01,  3.2525826e-01,
#               3.2249245e-01, -2.3070738e-01, -1.1058530e+00],            dtype=float32)

# %%
reconstructed_predicted_weights = pca.inverse_transform(predicted_weights)
reconstructed_predicted_weights = reconstruct_pytree_fn(reconstructed_predicted_weights)

# %% [markdown]
# ## Testing the model
# In this first experiment, we consider a *single* test example with a given configuration, i.e., a level of blurriness and predict the weights corresponding to the given configuration. After predicting the weights, we project back to the full-dimensional parameter space and predict the rest of the elements in the test set.

# %%
X_test = np.array(mnist_test.data)
y_test = np.array(mnist_test.targets)

# %%
ix = 4
radius = 2.0

shift_config = BlurRad(radius)
x_test_shift = shift_config(X_test[ix])
predicted_weights = weight_model.apply(params, x_test_shift.ravel())
reconstructed_predicted_weights = pca.inverse_transform(predicted_weights)
reconstructed_predicted_weights = reconstruct_pytree_fn(reconstructed_predicted_weights)

plt.imshow(x_test_shift)
plt.title(f"Blurriness: {radius:0.3f}")
plt.axis("off");

# %%
model.apply(reconstructed_predicted_weights, x_test_shift.ravel()).argmax()
# Out:
# DeviceArray(4, dtype=int32)

# %% [markdown]
# ### Predicting the rest of the corrupted digits

# %%
from sklearn.metrics import confusion_matrix

# %%
# %%time
X_test_shift = dojax.proc_dataset_multiple(radius, X_test, n_processes=90)
# Out:
# CPU times: user 22.6 ms, sys: 9.43 s, total: 9.45 s
# Wall time: 7.15 s

# %%
y_test_hat = model.apply(reconstructed_predicted_weights, X_test_shift.reshape(-1, 28 ** 2))
y_test_hat = y_test_hat.argmax(axis=1)

# %%
acc_target = (y_test_hat == y_test).mean()
acc_target
# Out:
# DeviceArray(0.82989997, dtype=float32)

# %% [markdown]
# ## Predicting for multiple radii
#
# In this section, we evaluate the perdictive performance of the single-shot learning for the weights

# %%
logger.add("projection-accuracy-full.log", rotation="5mb")
# Out:
# 1

# %%
ix = 4
accuracy_configs_learned = []

for i, radius in enumerate(radii[89:]):
    shift_config = BlurRad(radius)
    x_test_shift = shift_config(X_test[ix])
    predicted_weights = weight_model.apply(params, x_test_shift.ravel())
    reconstructed_predicted_weights = pca.inverse_transform(predicted_weights)
    reconstructed_predicted_weights = reconstruct_pytree_fn(reconstructed_predicted_weights)
    
    X_test_shift = dojax.proc_dataset_multiple(radius, X_test, n_processes=90)
    y_test_hat = model.apply(reconstructed_predicted_weights, X_test_shift.reshape(-1, 28 ** 2))
    y_test_hat = y_test_hat.argmax(axis=1)
    
    accuracy_learned = (y_test_hat == y_test).mean()
    accuracy_configs_learned.append(accuracy_learned)
    
    logger.info(f"{radius=:0.4f} | {accuracy_learned=:0.4f}")
# Out:
# 2022-03-03 05:10:28.081 | INFO     | __main__:<module>:18 - radius=2.6971 | accuracy_learned=0.5208
# https://symbolize.stripped_domain/r/?trace=7f0f81aa83f4,7f0f81aaa3bf,7f&map=
# *** SIGTERM received by PID 657965 (TID 657965) on cpu 45 from PID 655673; stack trace: ***
# PC: @     0x7f0f81aa83f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f0f713587fa        992  (unknown)
#     @     0x7f0f81aaa3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f0f81aa83f4,7f0f713587f9,7f0f81aaa3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f0f62980000-7f0f716c2d50
# E0303 05:10:34.810161  657965 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 05:10:34.839170  657965 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 05:10:35.091 | INFO     | __main__:<module>:18 - radius=2.7274 | accuracy_learned=0.5041
# https://symbolize.stripped_domain/r/?trace=7f0f81aa83f4,7f0f81aaa3bf,7f&map=
# *** SIGTERM received by PID 658101 (TID 658101) on cpu 95 from PID 655673; stack trace: ***
# PC: @     0x7f0f81aa83f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f0f713587fa        992  (unknown)
#     @     0x7f0f81aaa3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f0f81aa83f4,7f0f713587f9,7f0f81aaa3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f0f62980000-7f0f716c2d50
# E0303 05:10:41.736901  658101 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 05:10:41.766937  658101 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 05:10:42.020 | INFO     | __main__:<module>:18 - radius=2.7577 | accuracy_learned=0.4887
# https://symbolize.stripped_domain/r/?trace=7f0f81aa83f4,7f0f81aaa3bf,7f&map=
# *** SIGTERM received by PID 658106 (TID 658106) on cpu 15 from PID 655673; stack trace: ***
# PC: @     0x7f0f81aa83f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f0f713587fa        992  (unknown)
#     @     0x7f0f81aaa3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f0f81aa83f4,7f0f713587f9,7f0f81aaa3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f0f62980000-7f0f716c2d50
# E0303 05:10:48.739761  658106 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 05:10:48.767910  658106 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 05:10:49.046 | INFO     | __main__:<module>:18 - radius=2.7879 | accuracy_learned=0.4733
# 2022-03-03 05:10:56.250 | INFO     | __main__:<module>:18 - radius=2.8182 | accuracy_learned=0.4565
# 2022-03-03 05:11:03.427 | INFO     | __main__:<module>:18 - radius=2.8485 | accuracy_learned=0.4415
# 2022-03-03 05:11:10.461 | INFO     | __main__:<module>:18 - radius=2.8788 | accuracy_learned=0.4272
# 2022-03-03 05:11:17.499 | INFO     | __main__:<module>:18 - radius=2.9091 | accuracy_learned=0.4147
# 2022-03-03 05:11:24.521 | INFO     | __main__:<module>:18 - radius=2.9394 | accuracy_learned=0.4010
# 2022-03-03 05:11:31.575 | INFO     | __main__:<module>:18 - radius=2.9697 | accuracy_learned=0.3924
# 2022-03-03 05:11:38.646 | INFO     | __main__:<module>:18 - radius=3.0000 | accuracy_learned=0.3815

# %%
import re
with open("projection-accuracy-full.log", "r") as f:
    logs = f.read()
    
regexp = re.compile(r"radius=([0-9\.]+) \| accuracy_learned=([0-9\.]+)")

log_vals = []
for line in logs.split("\n")[:-1]:
    rad = regexp.search(line)[1]
    acc = regexp.search(line)[2]
    log_vals.append({"radius": float(rad), "accuracy": float(acc)})

# %%
log_df = pd.DataFrame(log_vals).set_index("radius")
log_df.plot()
plt.title("One-shot weight-prediction")
# Out:
# Text(0.5, 1.0, 'One-shot weight-prediction')

# %% [markdown]
# ### PCA-learned weights, PCA-projected weights and full-weights

# %%
logger.add("projection-accuracy-full.log", rotation="5mb")
# Out:
# 1

# %%
# Test-example index to predict the weights
ix = 4
accuracy_configs_learned = []

zipped_elements = zip(radii, hist_params_flat, params_proj)

for i, (radius, weights_flat_orig, weights_flat_proj) in enumerate(zipped_elements):
    shift_config = BlurRad(radius)
    X_test_shift_flat = (dojax.proc_dataset_multiple(radius, X_test, n_processes=90)
                              .reshape(-1, 28 ** 2))

    ### Parsing weights
    
    original_weights = reconstruct_pytree_fn(weights_flat_orig)

    projected_weights = pca.inverse_transform(weights_flat_proj)
    projected_weights = reconstruct_pytree_fn(projected_weights)
    
    x_test_shift = shift_config(X_test[ix])
    learned_weights = weight_model.apply(params, x_test_shift.ravel())
    learned_weights = pca.inverse_transform(learned_weights)
    learned_weights = reconstruct_pytree_fn(learned_weights)
    
    ### Evaluating model on sets of weights
    
    original_y_test_hat = model.apply(original_weights, X_test_shift_flat)
    original_y_test_hat = original_y_test_hat.argmax(axis=1)
    
    projected_y_test_hat = model.apply(projected_weights, X_test_shift_flat)
    projected_y_test_hat = projected_y_test_hat.argmax(axis=1)

    predicted_y_test_hat = model.apply(learned_weights, X_test_shift_flat)
    predicted_y_test_hat = predicted_y_test_hat.argmax(axis=1)

    accuracy_original = (original_y_test_hat == y_test).mean()
    accuracy_projected = (projected_y_test_hat == y_test).mean()
    accuracy_learned = (predicted_y_test_hat == y_test).mean()
    
    
    entry = {
        "radius": radius,
        "accuracy-original": accuracy_original,
        "accuracy-projected": accuracy_projected,
        "accuracy-learned": accuracy_learned
    }
    accuracy_configs_learned.append(entry)
    
    logstr = f"{radius=:0.4f} | {accuracy_original=:0.4f} | {accuracy_projected=:0.4f} | {accuracy_learned=:0.4f}"
    logger.info(logstr)
# Out:
# 2022-03-03 08:35:14.998 | INFO     | __main__:<module>:51 - radius=0.0010 | accuracy_original=0.9839 | accuracy_projected=0.9839 | accuracy_learned=0.9734
# 2022-03-03 08:35:23.696 | INFO     | __main__:<module>:51 - radius=0.0313 | accuracy_original=0.9839 | accuracy_projected=0.9839 | accuracy_learned=0.9734
# 2022-03-03 08:35:32.455 | INFO     | __main__:<module>:51 - radius=0.0616 | accuracy_original=0.9839 | accuracy_projected=0.9839 | accuracy_learned=0.9734
# 2022-03-03 08:35:41.321 | INFO     | __main__:<module>:51 - radius=0.0919 | accuracy_original=0.9838 | accuracy_projected=0.9755 | accuracy_learned=0.9734
# 2022-03-03 08:35:50.117 | INFO     | __main__:<module>:51 - radius=0.1222 | accuracy_original=0.9801 | accuracy_projected=0.9762 | accuracy_learned=0.9734
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 689888 (TID 689888) on cpu 25 from PID 686365; stack trace: ***
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:35:57.424529  689888 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:35:57.457336  689888 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:35:59.182 | INFO     | __main__:<module>:51 - radius=0.1525 | accuracy_original=0.9822 | accuracy_projected=0.9762 | accuracy_learned=0.9735
# 2022-03-03 08:36:08.023 | INFO     | __main__:<module>:51 - radius=0.1828 | accuracy_original=0.9803 | accuracy_projected=0.9768 | accuracy_learned=0.9734
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 690076 (TID 690076) on cpu 7 from PID 686365; stack trace: ***
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 690219 (TID 690219) on cpu 40 from PID 686365; stack trace: ***
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 690220 (TID 690220) on cpu 31 from PID 686365; stack trace: ***
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:36:15.127370  690076 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:36:15.134824  690219 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:36:15.135392  690220 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:36:15.158699  690076 process_state.cc:770] RAW: Raising signal 15 with default behavior
# E0303 08:36:15.166112  690219 process_state.cc:770] RAW: Raising signal 15 with default behavior
# E0303 08:36:15.170604  690220 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:36:16.865 | INFO     | __main__:<module>:51 - radius=0.2131 | accuracy_original=0.9828 | accuracy_projected=0.9762 | accuracy_learned=0.9733
# 2022-03-03 08:36:25.736 | INFO     | __main__:<module>:51 - radius=0.2433 | accuracy_original=0.9828 | accuracy_projected=0.9782 | accuracy_learned=0.9733
# 2022-03-03 08:36:34.786 | INFO     | __main__:<module>:51 - radius=0.2736 | accuracy_original=0.9808 | accuracy_projected=0.9786 | accuracy_learned=0.9735
# 2022-03-03 08:36:44.475 | INFO     | __main__:<module>:51 - radius=0.3039 | accuracy_original=0.9821 | accuracy_projected=0.9797 | accuracy_learned=0.9737
# 2022-03-03 08:36:53.875 | INFO     | __main__:<module>:51 - radius=0.3342 | accuracy_original=0.9786 | accuracy_projected=0.9764 | accuracy_learned=0.9741
# https://symbolize.stripped_domain/r/?trace=55b00123d7cb,7f89f3a9a3bf&map=
# *** SIGTERM received by PID 690911 (TID 690911) on cpu 17 from PID 686365; stack trace: ***
# PC: @     0x55b00123d7cb  (unknown)  _PyFunction_Vectorcall
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  (unknown)  (unknown)
#     @ ... and at least 1 more frames
# https://symbolize.stripped_domain/r/?trace=55b00123d7cb,7f89e33487f9,7f89f3a9a3bf&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:37:01.867686  690911 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:37:01.884027  690911 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:37:03.626 | INFO     | __main__:<module>:51 - radius=0.3645 | accuracy_original=0.9809 | accuracy_projected=0.9800 | accuracy_learned=0.9740
# 2022-03-03 08:37:13.273 | INFO     | __main__:<module>:51 - radius=0.3948 | accuracy_original=0.9805 | accuracy_projected=0.9751 | accuracy_learned=0.9737
# 2022-03-03 08:37:22.913 | INFO     | __main__:<module>:51 - radius=0.4251 | accuracy_original=0.9830 | accuracy_projected=0.9780 | accuracy_learned=0.9732
# 2022-03-03 08:37:32.180 | INFO     | __main__:<module>:51 - radius=0.4554 | accuracy_original=0.9835 | accuracy_projected=0.9741 | accuracy_learned=0.9732
# 2022-03-03 08:37:41.027 | INFO     | __main__:<module>:51 - radius=0.4857 | accuracy_original=0.9820 | accuracy_projected=0.9649 | accuracy_learned=0.9732
# 2022-03-03 08:37:50.133 | INFO     | __main__:<module>:51 - radius=0.5160 | accuracy_original=0.9815 | accuracy_projected=0.9771 | accuracy_learned=0.9731
# 2022-03-03 08:37:59.567 | INFO     | __main__:<module>:51 - radius=0.5463 | accuracy_original=0.9827 | accuracy_projected=0.9724 | accuracy_learned=0.9729
# 2022-03-03 08:38:08.566 | INFO     | __main__:<module>:51 - radius=0.5766 | accuracy_original=0.9810 | accuracy_projected=0.9676 | accuracy_learned=0.9719
# 2022-03-03 08:38:17.612 | INFO     | __main__:<module>:51 - radius=0.6069 | accuracy_original=0.9837 | accuracy_projected=0.9676 | accuracy_learned=0.9716
# 2022-03-03 08:38:26.833 | INFO     | __main__:<module>:51 - radius=0.6372 | accuracy_original=0.9814 | accuracy_projected=0.9684 | accuracy_learned=0.9713
# 2022-03-03 08:38:35.950 | INFO     | __main__:<module>:51 - radius=0.6674 | accuracy_original=0.9805 | accuracy_projected=0.9681 | accuracy_learned=0.9709
# 2022-03-03 08:38:44.791 | INFO     | __main__:<module>:51 - radius=0.6977 | accuracy_original=0.9833 | accuracy_projected=0.9770 | accuracy_learned=0.9690
# 2022-03-03 08:38:53.656 | INFO     | __main__:<module>:51 - radius=0.7280 | accuracy_original=0.9816 | accuracy_projected=0.9650 | accuracy_learned=0.9678
# 2022-03-03 08:39:03.267 | INFO     | __main__:<module>:51 - radius=0.7583 | accuracy_original=0.9793 | accuracy_projected=0.9715 | accuracy_learned=0.9654
# 2022-03-03 08:39:12.600 | INFO     | __main__:<module>:51 - radius=0.7886 | accuracy_original=0.9805 | accuracy_projected=0.9761 | accuracy_learned=0.9645
# 2022-03-03 08:39:21.789 | INFO     | __main__:<module>:51 - radius=0.8189 | accuracy_original=0.9811 | accuracy_projected=0.9757 | accuracy_learned=0.9640
# 2022-03-03 08:39:30.603 | INFO     | __main__:<module>:51 - radius=0.8492 | accuracy_original=0.9811 | accuracy_projected=0.9752 | accuracy_learned=0.9636
# 2022-03-03 08:39:40.229 | INFO     | __main__:<module>:51 - radius=0.8795 | accuracy_original=0.9780 | accuracy_projected=0.9738 | accuracy_learned=0.9632
# https://symbolize.stripped_domain/r/?trace=55b001282a91,7f89f3a9a3bf,7f877205577f&map=
# *** SIGTERM received by PID 693843 (TID 693843) on cpu 61 from PID 686365; stack trace: ***
# PC: @     0x55b001282a91  (unknown)  _PyEval_EvalFrameDefault
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  (unknown)  (unknown)
#     @     0x7f8772055780  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=55b001282a91,7f89e33487f9,7f89f3a9a3bf,7f877205577f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:39:47.768816  693843 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:39:47.804649  693843 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:39:49.525 | INFO     | __main__:<module>:51 - radius=0.9098 | accuracy_original=0.9819 | accuracy_projected=0.9789 | accuracy_learned=0.9631
# 2022-03-03 08:39:58.754 | INFO     | __main__:<module>:51 - radius=0.9401 | accuracy_original=0.9712 | accuracy_projected=0.9717 | accuracy_learned=0.9626
# 2022-03-03 08:40:07.562 | INFO     | __main__:<module>:51 - radius=0.9704 | accuracy_original=0.9800 | accuracy_projected=0.9770 | accuracy_learned=0.9614
# 2022-03-03 08:40:16.718 | INFO     | __main__:<module>:51 - radius=1.0007 | accuracy_original=0.9775 | accuracy_projected=0.9715 | accuracy_learned=0.9604
# 2022-03-03 08:40:25.527 | INFO     | __main__:<module>:51 - radius=1.0310 | accuracy_original=0.9816 | accuracy_projected=0.9788 | accuracy_learned=0.9598
# 2022-03-03 08:40:35.043 | INFO     | __main__:<module>:51 - radius=1.0613 | accuracy_original=0.9800 | accuracy_projected=0.9806 | accuracy_learned=0.9584
# 2022-03-03 08:40:43.837 | INFO     | __main__:<module>:51 - radius=1.0915 | accuracy_original=0.9806 | accuracy_projected=0.9771 | accuracy_learned=0.9564
# 2022-03-03 08:40:52.818 | INFO     | __main__:<module>:51 - radius=1.1218 | accuracy_original=0.9768 | accuracy_projected=0.9768 | accuracy_learned=0.9552
# 2022-03-03 08:41:01.889 | INFO     | __main__:<module>:51 - radius=1.1521 | accuracy_original=0.9783 | accuracy_projected=0.9774 | accuracy_learned=0.9537
# 2022-03-03 08:41:10.941 | INFO     | __main__:<module>:51 - radius=1.1824 | accuracy_original=0.9759 | accuracy_projected=0.9760 | accuracy_learned=0.9524
# 2022-03-03 08:41:20.020 | INFO     | __main__:<module>:51 - radius=1.2127 | accuracy_original=0.9767 | accuracy_projected=0.9723 | accuracy_learned=0.9501
# 2022-03-03 08:41:29.226 | INFO     | __main__:<module>:51 - radius=1.2430 | accuracy_original=0.9797 | accuracy_projected=0.9792 | accuracy_learned=0.9474
# 2022-03-03 08:41:38.032 | INFO     | __main__:<module>:51 - radius=1.2733 | accuracy_original=0.9776 | accuracy_projected=0.9754 | accuracy_learned=0.9444
# 2022-03-03 08:41:46.786 | INFO     | __main__:<module>:51 - radius=1.3036 | accuracy_original=0.9762 | accuracy_projected=0.9730 | accuracy_learned=0.9413
# 2022-03-03 08:41:55.584 | INFO     | __main__:<module>:51 - radius=1.3339 | accuracy_original=0.9767 | accuracy_projected=0.9770 | accuracy_learned=0.9373
# 2022-03-03 08:42:04.385 | INFO     | __main__:<module>:51 - radius=1.3642 | accuracy_original=0.9672 | accuracy_projected=0.9670 | accuracy_learned=0.9342
# 2022-03-03 08:42:13.260 | INFO     | __main__:<module>:51 - radius=1.3945 | accuracy_original=0.9746 | accuracy_projected=0.9713 | accuracy_learned=0.9318
# 2022-03-03 08:42:22.343 | INFO     | __main__:<module>:51 - radius=1.4248 | accuracy_original=0.9654 | accuracy_projected=0.9489 | accuracy_learned=0.9304
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 696953 (TID 696953) on cpu 95 from PID 686365; stack trace: ***
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:42:29.357941  696953 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:42:29.388480  696953 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:42:31.170 | INFO     | __main__:<module>:51 - radius=1.4551 | accuracy_original=0.9621 | accuracy_projected=0.9014 | accuracy_learned=0.9268
# 2022-03-03 08:42:39.977 | INFO     | __main__:<module>:51 - radius=1.4854 | accuracy_original=0.9749 | accuracy_projected=0.9718 | accuracy_learned=0.9234
# 2022-03-03 08:42:48.716 | INFO     | __main__:<module>:51 - radius=1.5156 | accuracy_original=0.9804 | accuracy_projected=0.9778 | accuracy_learned=0.9196
# 2022-03-03 08:42:57.906 | INFO     | __main__:<module>:51 - radius=1.5459 | accuracy_original=0.9684 | accuracy_projected=0.9694 | accuracy_learned=0.9161
# 2022-03-03 08:43:06.672 | INFO     | __main__:<module>:51 - radius=1.5762 | accuracy_original=0.9714 | accuracy_projected=0.9699 | accuracy_learned=0.9124
# 2022-03-03 08:43:15.514 | INFO     | __main__:<module>:51 - radius=1.6065 | accuracy_original=0.9697 | accuracy_projected=0.9721 | accuracy_learned=0.9088
# 2022-03-03 08:43:24.654 | INFO     | __main__:<module>:51 - radius=1.6368 | accuracy_original=0.9683 | accuracy_projected=0.9653 | accuracy_learned=0.9043
# https://symbolize.stripped_domain/r/?trace=55b0011edac2,7f89f3a9a3bf,55b00144411f&map=
# *** SIGTERM received by PID 697953 (TID 697953) on cpu 68 from PID 686365; stack trace: ***
# PC: @     0x55b0011edac2  (unknown)  PyObject_GetAttr
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  (unknown)  (unknown)
#     @     0x55b001444120  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=55b0011edac2,7f89e33487f9,7f89f3a9a3bf,55b00144411f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:43:31.813044  697953 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:43:31.844233  697953 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:43:33.588 | INFO     | __main__:<module>:51 - radius=1.6671 | accuracy_original=0.9682 | accuracy_projected=0.9557 | accuracy_learned=0.8999
# 2022-03-03 08:43:42.340 | INFO     | __main__:<module>:51 - radius=1.6974 | accuracy_original=0.9662 | accuracy_projected=0.9556 | accuracy_learned=0.8949
# 2022-03-03 08:43:51.212 | INFO     | __main__:<module>:51 - radius=1.7277 | accuracy_original=0.9680 | accuracy_projected=0.9615 | accuracy_learned=0.8885
# 2022-03-03 08:43:59.979 | INFO     | __main__:<module>:51 - radius=1.7580 | accuracy_original=0.9609 | accuracy_projected=0.9513 | accuracy_learned=0.8821
# 2022-03-03 08:44:08.751 | INFO     | __main__:<module>:51 - radius=1.7883 | accuracy_original=0.9670 | accuracy_projected=0.9509 | accuracy_learned=0.8765
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 698903 (TID 698903) on cpu 95 from PID 686365; stack trace: ***
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:44:15.729595  698903 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:44:15.781319  698903 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:44:18.154 | INFO     | __main__:<module>:51 - radius=1.8186 | accuracy_original=0.9640 | accuracy_projected=0.9663 | accuracy_learned=0.8704
# 2022-03-03 08:44:26.955 | INFO     | __main__:<module>:51 - radius=1.8489 | accuracy_original=0.9603 | accuracy_projected=0.9641 | accuracy_learned=0.8644
# 2022-03-03 08:44:35.759 | INFO     | __main__:<module>:51 - radius=1.8792 | accuracy_original=0.9608 | accuracy_projected=0.9547 | accuracy_learned=0.8568
# 2022-03-03 08:44:44.954 | INFO     | __main__:<module>:51 - radius=1.9095 | accuracy_original=0.9572 | accuracy_projected=0.9534 | accuracy_learned=0.8521
# 2022-03-03 08:44:53.684 | INFO     | __main__:<module>:51 - radius=1.9397 | accuracy_original=0.9574 | accuracy_projected=0.9188 | accuracy_learned=0.8452
# 2022-03-03 08:45:02.377 | INFO     | __main__:<module>:51 - radius=1.9700 | accuracy_original=0.9539 | accuracy_projected=0.8843 | accuracy_learned=0.8379
# 2022-03-03 08:45:11.074 | INFO     | __main__:<module>:51 - radius=2.0003 | accuracy_original=0.9413 | accuracy_projected=0.8313 | accuracy_learned=0.8299
# 2022-03-03 08:45:19.878 | INFO     | __main__:<module>:51 - radius=2.0306 | accuracy_original=0.9273 | accuracy_projected=0.9043 | accuracy_learned=0.8226
# 2022-03-03 08:45:28.669 | INFO     | __main__:<module>:51 - radius=2.0609 | accuracy_original=0.9507 | accuracy_projected=0.9055 | accuracy_learned=0.8138
# 2022-03-03 08:45:37.371 | INFO     | __main__:<module>:51 - radius=2.0912 | accuracy_original=0.9500 | accuracy_projected=0.9042 | accuracy_learned=0.8050
# 2022-03-03 08:45:47.745 | INFO     | __main__:<module>:51 - radius=2.1215 | accuracy_original=0.9355 | accuracy_projected=0.8817 | accuracy_learned=0.7899
# 2022-03-03 08:45:56.632 | INFO     | __main__:<module>:51 - radius=2.1518 | accuracy_original=0.9459 | accuracy_projected=0.8999 | accuracy_learned=0.7826
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 700826 (TID 700826) on cpu 95 from PID 686365; stack trace: ***
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:46:03.618357  700826 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:46:03.659326  700826 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:46:05.457 | INFO     | __main__:<module>:51 - radius=2.1821 | accuracy_original=0.9388 | accuracy_projected=0.8855 | accuracy_learned=0.7704
# 2022-03-03 08:46:14.595 | INFO     | __main__:<module>:51 - radius=2.2124 | accuracy_original=0.9359 | accuracy_projected=0.6967 | accuracy_learned=0.7565
# 2022-03-03 08:46:23.358 | INFO     | __main__:<module>:51 - radius=2.2427 | accuracy_original=0.9473 | accuracy_projected=0.7360 | accuracy_learned=0.7439
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89f3a9a3bf,7f&map=
# *** SIGTERM received by PID 701311 (TID 701311) on cpu 95 from PID 686365; stack trace: ***
# PC: @     0x7f89f3a983f4  (unknown)  do_futex_wait.constprop.0
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  376208528  (unknown)
#     @               0x80  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3a983f4,7f89e33487f9,7f89f3a9a3bf,7f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:46:30.385590  701311 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:46:30.417009  701311 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:46:32.125 | INFO     | __main__:<module>:51 - radius=2.2730 | accuracy_original=0.9331 | accuracy_projected=0.6708 | accuracy_learned=0.7294
# https://symbolize.stripped_domain/r/?trace=7f89f3c40ea7,7f89f3a9a3bf,55b00143d73f&map=
# *** SIGTERM received by PID 701337 (TID 701337) on cpu 8 from PID 686365; stack trace: ***
# PC: @     0x7f89f3c40ea7  (unknown)  operator delete[]()
#     @     0x7f89e33487fa        992  (unknown)
#     @     0x7f89f3a9a3c0  (unknown)  (unknown)
#     @     0x55b00143d740  (unknown)  (unknown)
# https://symbolize.stripped_domain/r/?trace=7f89f3c40ea7,7f89e33487f9,7f89f3a9a3bf,55b00143d73f&map=7a511a57244151c993b16b37978e7ed7:7f89d4970000-7f89e36b2d50
# E0303 08:46:39.190316  701337 coredump_hook.cc:320] RAW: Remote crash gathering disabled for SIGTERM.
# E0303 08:46:39.253563  701337 process_state.cc:770] RAW: Raising signal 15 with default behavior
# 2022-03-03 08:46:40.987 | INFO     | __main__:<module>:51 - radius=2.3033 | accuracy_original=0.9233 | accuracy_projected=0.5959 | accuracy_learned=0.7156
# 2022-03-03 08:46:49.830 | INFO     | __main__:<module>:51 - radius=2.3336 | accuracy_original=0.9292 | accuracy_projected=0.3845 | accuracy_learned=0.7007
# 2022-03-03 08:46:58.678 | INFO     | __main__:<module>:51 - radius=2.3638 | accuracy_original=0.9183 | accuracy_projected=0.8047 | accuracy_learned=0.6866
# 2022-03-03 08:47:07.740 | INFO     | __main__:<module>:51 - radius=2.3941 | accuracy_original=0.9245 | accuracy_projected=0.7019 | accuracy_learned=0.6734
# 2022-03-03 08:47:16.424 | INFO     | __main__:<module>:51 - radius=2.4244 | accuracy_original=0.9146 | accuracy_projected=0.4475 | accuracy_learned=0.6551
# 2022-03-03 08:47:25.204 | INFO     | __main__:<module>:51 - radius=2.4547 | accuracy_original=0.9141 | accuracy_projected=0.3725 | accuracy_learned=0.6415
# 2022-03-03 08:47:33.968 | INFO     | __main__:<module>:51 - radius=2.4850 | accuracy_original=0.9171 | accuracy_projected=0.7351 | accuracy_learned=0.6281
# 2022-03-03 08:47:42.710 | INFO     | __main__:<module>:51 - radius=2.5153 | accuracy_original=0.8939 | accuracy_projected=0.3619 | accuracy_learned=0.6139
# 2022-03-03 08:47:51.489 | INFO     | __main__:<module>:51 - radius=2.5456 | accuracy_original=0.8943 | accuracy_projected=0.4140 | accuracy_learned=0.5990
# 2022-03-03 08:48:00.195 | INFO     | __main__:<module>:51 - radius=2.5759 | accuracy_original=0.9099 | accuracy_projected=0.4207 | accuracy_learned=0.5832
# 2022-03-03 08:48:09.174 | INFO     | __main__:<module>:51 - radius=2.6062 | accuracy_original=0.8831 | accuracy_projected=0.2751 | accuracy_learned=0.5677
# 2022-03-03 08:48:17.973 | INFO     | __main__:<module>:51 - radius=2.6365 | accuracy_original=0.8869 | accuracy_projected=0.1704 | accuracy_learned=0.5546
# 2022-03-03 08:48:26.823 | INFO     | __main__:<module>:51 - radius=2.6668 | accuracy_original=0.9140 | accuracy_projected=0.3017 | accuracy_learned=0.5371
# 2022-03-03 08:48:35.724 | INFO     | __main__:<module>:51 - radius=2.6971 | accuracy_original=0.8795 | accuracy_projected=0.2335 | accuracy_learned=0.5230
# 2022-03-03 08:48:44.513 | INFO     | __main__:<module>:51 - radius=2.7274 | accuracy_original=0.8834 | accuracy_projected=0.2751 | accuracy_learned=0.5074
# 2022-03-03 08:48:53.339 | INFO     | __main__:<module>:51 - radius=2.7577 | accuracy_original=0.8679 | accuracy_projected=0.2886 | accuracy_learned=0.4909
# 2022-03-03 08:49:02.232 | INFO     | __main__:<module>:51 - radius=2.7879 | accuracy_original=0.8814 | accuracy_projected=0.2248 | accuracy_learned=0.4754
# 2022-03-03 08:49:11.021 | INFO     | __main__:<module>:51 - radius=2.8182 | accuracy_original=0.8909 | accuracy_projected=0.2911 | accuracy_learned=0.4597
# 2022-03-03 08:49:19.768 | INFO     | __main__:<module>:51 - radius=2.8485 | accuracy_original=0.8841 | accuracy_projected=0.2451 | accuracy_learned=0.4452
# 2022-03-03 08:49:28.565 | INFO     | __main__:<module>:51 - radius=2.8788 | accuracy_original=0.9064 | accuracy_projected=0.2182 | accuracy_learned=0.4308
# 2022-03-03 08:49:37.490 | INFO     | __main__:<module>:51 - radius=2.9091 | accuracy_original=0.8757 | accuracy_projected=0.1821 | accuracy_learned=0.4172
# 2022-03-03 08:49:46.378 | INFO     | __main__:<module>:51 - radius=2.9394 | accuracy_original=0.8375 | accuracy_projected=0.2650 | accuracy_learned=0.4055
# 2022-03-03 08:49:55.262 | INFO     | __main__:<module>:51 - radius=2.9697 | accuracy_original=0.8511 | accuracy_projected=0.2568 | accuracy_learned=0.3953
# 2022-03-03 08:50:04.046 | INFO     | __main__:<module>:51 - radius=3.0000 | accuracy_original=0.8798 | accuracy_projected=0.2348 | accuracy_learned=0.3835

# %%
acc_hist = accuracy_configs_learned[1::2]
df_hist = []
for row in acc_hist:
    df_hist.append({k: float(v) for k,v in row.items()})

# %%
pd.DataFrame(df_hist).set_index("radius").plot()
# Out:
# <AxesSubplot:xlabel='radius'>

# %% [markdown]
# ## Comparing performance for currupted test data on original weights

# %%
hist_params_flat_projected_full = pca.inverse_transform(params_proj)
accuracy_configs_proj = []
accuracy_configs_original = []

for it, (weights_flat_proj, weights_flat_orig) in enumerate(zip(hist_params_flat_projected_full, hist_params_flat)):
    print(f"{it}", end="\r")
    
    original_weights = reconstruct_pytree_fn(weights_flat_orig)
    projected_weights = reconstruct_pytree_fn(weights_flat_proj)
    
    X_test_shift_flat = X_test_shift.reshape(-1, 28 ** 2)

    original_y_test_hat = model.apply(original_weights, X_test_shift_flat)
    original_y_test_hat = original_y_test_hat.argmax(axis=1)
    
    projected_y_test_hat = model.apply(projected_weights, X_test_shift_flat)
    projected_y_test_hat = projected_y_test_hat.argmax(axis=1)

    accuracy_original = (original_y_test_hat == y_test).mean()
    accuracy_projected = (projected_y_test_hat == y_test).mean()
    
    
    accuracy_configs_original.append(accuracy_original)
    accuracy_configs_proj.append(accuracy_projected)
# Out:
# 99

# %%
plt.title(f"Blurriness {radius}")
plt.plot(radii, accuracy_configs_original, label="original")
plt.plot(radii, accuracy_configs_proj, label="projected")
plt.scatter(radius, acc_target, c="tab:purple")
plt.legend();

# %% [markdown]
# * Train the model on the pieces and see how it interpolates.
